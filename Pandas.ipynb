# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAyman-2237/Mohamed-Ayman-Programming-Using-C/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
emp = pd.Series(['Parker', 'John', 'Smith', 'William'])
id=pd.Series([102, 107, 109, 114])
frame = {'Emp': emp, 'ID': id}
result = pd.DataFrame(frame)
print("\nSeries to Data frame\n")
print(result)
# Out:
# Series to Data frame
#
#        Emp   ID
# 0   Parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114
